# %%
import pandas as pd
import seaborn as sns

# %%
aapl = pd.read_csv("dataset/timeseries/AAPL_timeseries.csv")[["Date","Close"]]
msft = pd.read_csv("dataset/timeseries/MSFT_timeseries.csv")[["Date","Close"]]
cvx = pd.read_csv("dataset/timeseries/CVX_timeseries.csv")[["Date","Close"]]
sbux = pd.read_csv("dataset/timeseries/SBUX_timeseries.csv")[["Date","Close"]]
azn = pd.read_csv("dataset/timeseries/AZN_timeseries.csv")[["Date","Close"]]

# %%
aapl["Date"]=aapl["Date"].str[0:10]
msft["Date"]=msft["Date"].str[0:10]
cvx["Date"]=cvx["Date"].str[0:10]
sbux["Date"]=sbux["Date"].str[0:10]
azn["Date"]=azn["Date"].str[0:10]

# %%
aapl
# Out:
#             Date       Close
# 0     2014-01-24   17.097677
# 1     2014-01-27   17.236380
# 2     2014-01-28   15.858727
# 3     2014-01-29   15.678689
# 4     2014-01-30   15.648315
# ...          ...         ...
# 2511  2024-01-17  182.679993
# 2512  2024-01-18  188.630005
# 2513  2024-01-19  191.559998
# 2514  2024-01-22  193.889999
# 2515  2024-01-23  195.179993
#
# [2516 rows x 2 columns]

# %%
aapl["Date"]=pd.to_datetime(aapl["Date"])
msft["Date"]=pd.to_datetime(msft["Date"])
sbux["Date"]=pd.to_datetime(sbux["Date"])
cvx["Date"]=pd.to_datetime(cvx["Date"])
azn["Date"]=pd.to_datetime(azn["Date"])

# %%
#df = pd.merge([aapl,msft,sbux,cvx,azn], on='Date', how='inner')

# %%
sns.set_theme(style="darkgrid")

# %%
sns.lineplot(x="Date", y="Close",
            data=msft)
# Out:
# <Axes: xlabel='Date', ylabel='Close'>
